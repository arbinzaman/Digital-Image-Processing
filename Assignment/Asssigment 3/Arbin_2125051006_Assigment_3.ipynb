# %%
from google.colab import files
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image1 = np.ones((400, 400, 3), dtype=np.uint8) * 255
cv2.rectangle(image1, (150, 150), (250, 250), (0, 255, 0), -1)


image2 = np.ones((400, 400, 3), dtype=np.uint8) * 255
cv2.circle(image2, (200, 200), 75, (255, 0, 255), -1)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
bitwise_and = cv2.bitwise_and(image1, image2)

cv2_imshow(bitwise_and)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
bitwise_or = cv2.bitwise_or(image1, image2)
cv2_imshow(bitwise_or)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
bitwise_xor = cv2.bitwise_xor(image1, image2)
cv2_imshow(bitwise_xor)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
bitwise_not1 = cv2.bitwise_not(image1)
cv2_imshow(bitwise_not1)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
bitwise_not2 = cv2.bitwise_not(image2)
cv2_imshow(bitwise_not2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
multiplication = cv2.multiply(image1, image2)

cv2_imshow(multiplication)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
alpha = 0.5
blended = cv2.addWeighted(image1, alpha, image2, 1 - alpha, 0)

cv2_imshow(blended)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
subtraction = cv2.subtract(image1, image2)
cv2_imshow(subtraction)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
