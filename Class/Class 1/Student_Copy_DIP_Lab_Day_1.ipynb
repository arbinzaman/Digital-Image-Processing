# %% [markdown]
# # Digital Image Processing Lab
#
# **Author:** Audity Ghosh
# **Lecturer**, Department of Computer Science & Engineering, University of Information Technology and Sciences (UITS)
#
# **Course Code:** CSE 438
# **Course Title:** Digital Image Processing Lab
# **Section:** 8A (50th Batch)
# **Date:** 29 January, 2025
#
# ---
#
# ## Experiment No. 1: Image Loading, Displaying, and Saving
#
# ### 1.a) Read, Display, and Save an Image [From Google Drive]
# In this part of the experiment, we will write a program that:
# - Reads an image stored on Google Drive.
# - Displays the image using Matplotlib.
# - Saves the image to a new location in Google Drive.
#
# ### 1.b) Read, Save, and Display an Image [From URL]
# In this section, we will demonstrate how to:
# - Read an image from a given URL.
# - Display the image using Matplotlib.
# - Save the image to a specified location.
#
# By the end of this experiment, you will be able to handle both local and online images in Python using OpenCV and Matplotlib.

# %% [markdown]
# Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive') # Mounting to /content/drive
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import necessary libraries

# %%
from google.colab import files
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import urllib.request
import numpy as np

# %% [markdown]
# # Experiement No. 1

# %% [markdown]
# ## 1. a)	Write a program to read, display and write an image. [From Drive]

# %%
# Step 1: Provide the image path in your Google Drive
# Replace with the actual path to your image file
image_path = '/content/drive/MyDrive/UITS/Eight Semester/Digital Image Processing/pizza.jpg'

# %%
# Step 2: Read the image using OpenCV
img = cv2.imread(image_path)  # OpenCV reads images in BGR format

# %%
# Step 3: Convert BGR to RGB for correct display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Step 4: Display the image using Matplotlib
plt.imshow(img)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Image from Google Drive")
plt.show()

# %%
# Step 5: Write/Save the image to a new file
output_path = '/content/drive/MyDrive/UITS/Eight Semester/Digital Image Processing/pizza.jpg'
cv2.imwrite(output_path, img)
print(f"Image saved at: {output_path}")
# Out:
# Image saved at: /content/drive/MyDrive/UITS/Eight Semester/Digital Image Processing/pizza.jpg

# %% [markdown]
# ## 1. b)	Write a program to read, write and display an image. [From URL]

# %%
# Step 1: Provide the URL of the image
image_url = 'https://cdn.loveandlemons.com/wp-content/uploads/2023/02/vegetarian-pizza-recipe-580x870.jpg'  # Replace with the actual URL

# %%
# Step 2: Download the image using urllib
with urllib.request.urlopen(image_url) as response:
    img_array = np.asarray(bytearray(response.read()), dtype=np.uint8)  # Convert to NumPy array

# %%
# Step 3: Decode the image (convert it into OpenCV format)
img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)  # Decode as a color image (BGR format)

# %%
# Step 4: Convert BGR to RGB for correct display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Step 5: Display the image using Matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Image from URL")
plt.show()

# %%
# Step 6: Save the image locally
output_path = '/content/drive/MyDrive/UITS/Eight Semester/Digital Image Processing/output.jpg'
cv2.imwrite(output_path, img)
print(f"Image saved as: {output_path}")
# Out:
# Image saved as: /content/drive/MyDrive/UITS/Eight Semester/Digital Image Processing/output.jpg

# %%
# Example usage (assuming 'image_path' is defined as in the previous code)
gray_img = convert_to_grayscale(image_path)

if gray_img is not None:
    # Display the grayscale image using Matplotlib
    plt.imshow(gray_img, cmap='gray')  # Use 'gray' colormap for grayscale display
    plt.axis('off')
    plt.title("Grayscale Image")
    plt.show()

    # Save the grayscale image
    output_path_gray = '/content/drive/MyDrive/UITS/Eight Semester/Digital Image Processing/pizza_gray.jpg'
    cv2.imwrite(output_path_gray, gray_img)
    print(f"Grayscale image saved at: {output_path_gray}")
# Out:
# Grayscale image saved at: /content/drive/MyDrive/UITS/Eight Semester/Digital Image Processing/pizza_gray.jpg
